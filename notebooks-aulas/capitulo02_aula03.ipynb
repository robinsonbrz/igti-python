# %%
# Erros de Sintaxe

# %%
x = 10
y = 5
print(x + y)
# Out:
# 15

# %%
if x == 3:
    print('x é igual à 3')
    print('fim do bloco de código')

# %%
# Erros em Tempo de Execução

# %%
a = 1000
print(a)
b = 0
print(b)
c = a / b
print(c)
# Out:
# 1000
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\Max\vscode-proj\04-IGTI\igti-python\notebooks-aulas\capitulo02_aula03.ipynb Célula: 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Max/vscode-proj/04-IGTI/igti-python/notebooks-aulas/capitulo02_aula03.ipynb#ch0000004?line=2'>3</a> b = 0
#       <a href='vscode-notebook-cell:/c%3A/Users/Max/vscode-proj/04-IGTI/igti-python/notebooks-aulas/capitulo02_aula03.ipynb#ch0000004?line=3'>4</a> print(b)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Max/vscode-proj/04-IGTI/igti-python/notebooks-aulas/capitulo02_aula03.ipynb#ch0000004?line=4'>5</a> c = a / b
#       <a href='vscode-notebook-cell:/c%3A/Users/Max/vscode-proj/04-IGTI/igti-python/notebooks-aulas/capitulo02_aula03.ipynb#ch0000004?line=5'>6</a> print(c)
#
# ZeroDivisionError: division by zero

# %%
cidade = 'Belo Horizonte'
print(cidade)
estado = 'Minas Gerais'
print(estado)
print(cidade, estado, pais)
# Out:
# Belo Horizonte
# Minas Gerais
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Max\vscode-proj\04-IGTI\igti-python\notebooks-aulas\capitulo02_aula03.ipynb Célula: 6 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Max/vscode-proj/04-IGTI/igti-python/notebooks-aulas/capitulo02_aula03.ipynb#ch0000005?line=2'>3</a> estado = 'Minas Gerais'
#       <a href='vscode-notebook-cell:/c%3A/Users/Max/vscode-proj/04-IGTI/igti-python/notebooks-aulas/capitulo02_aula03.ipynb#ch0000005?line=3'>4</a> print(estado)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Max/vscode-proj/04-IGTI/igti-python/notebooks-aulas/capitulo02_aula03.ipynb#ch0000005?line=4'>5</a> print(cidade, estado, pais)
#
# NameError: name 'pais' is not defined

# %%
cidade = 'Belo Horizonte'
print(cidade)
1estado = 'Minas Gerais'
print(1estado)
print(cidade, 1estado, pais)
# Out:
#   Input In [8]
#     1estado = 'Minas Gerais'
#     ^
# SyntaxError: invalid decimal literal

# %%
# Erros Lógicos

# %%
x = 5.0
y = 7.0
z = 12.0
media = x + y + z / 3
#media = 5 + 7 + 12 / 3
#media = 5 + 7 + 4 = 16
print(media)
# Out:
# 16.0

# %%
x = 5.0
y = 7.0
z = 12.0
media = (x + y + z) / 3
print(media)
# Out:
# 8.0
