# %%
nome = 'Robinson Enedino'
print('Olá', nome, 'seja bem-vindo!')
# Out:
# Olá Robinson Enedino seja bem-vindo!

# %%
pessoa = 'Robinson Enedino'
print('Olá', pessoa)
# Out:
# Olá Robinson Enedino

# %%
numero = 1
numero + 2
numero + 99
# Out:
# 100
